# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
unique_player_count = purchase_data["SN"].nunique()#count the number of uniques values in Column SN
pd.DataFrame({"Total Players": [unique_player_count]}) #create data frame with number of unique players
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_item_count = purchase_data["Item ID"].nunique()#count the number of unique numbers in Column Item ID
average_price = purchase_data["Price"].mean() #Average of Column Price
number_of_purchases = purchase_data["Purchase ID"].nunique()#count the number of unique numbers in Column Purchase ID
total_revenue = purchase_data["Price"].sum()#add everything in Column Price

df = pd.DataFrame({"Number of Unique Items" : unique_item_count, "Average Price" : average_price, "Number of Purchases" : number_of_purchases, "Total Revenue" : total_revenue}, index = [0])
df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     183       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
total_each_gender = purchase_data["Gender"].value_counts()
percent = total_each_gender / unique_player_count *100
pd.DataFrame({"Total Count": total_each_gender, "Percentage of Players": percent})
# Out:
#                        Total Count  Percentage of Players
# Male                           652             113.194444
# Female                         113              19.618056
# Other / Non-Disclosed           15               2.604167

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = purchase_data.groupby(["Gender"]).count()["Price"]
avg_price = purchase_data.groupby(["Gender"]).mean()["Price"]
total_purch = purchase_data.groupby(["Gender"]).sum()["Price"]

    

pd.DataFrame({"Purchase Count": purchase_count, "Average Purchase Price" : avg_price, "Total Purchse" : total_purch})
# Out:
#                        Purchase Count  Average Purchase Price  Total Purchse
# Gender
# Female                            113                3.203009         361.94
# Male                              652                3.017853        1967.64
# Other / Non-Disclosed              15                3.346000          50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#Establish bins for ages
bins = [0, 9.5, 14.5, 19.5, 24.5, 29.5, 34.5, 39.5, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#Categorize the existing players using the age bins. Hint: use pd.cut()
purchase_data["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=group_names)

#Percentage calc then Dataframe same as before
total_each_age = purchase_data["Age Ranges"].value_counts()
percent = total_each_age / unique_player_count *100


pd.DataFrame({"Total Count": total_each_age, "Percentage of Players": percent})
# Out:
#        Total Count  Percentage of Players
# 20-24          365              63.368056
# 15-19          136              23.611111
# 25-29          101              17.534722
# 30-34           73              12.673611
# 35-39           41               7.118056
# 10-14           28               4.861111
# <10             23               3.993056
# 40+             13               2.256944

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=group_names)

#same as above
purchase_count = purchase_data.groupby(["Age Ranges"]).count()["Price"]
avg_price = purchase_data.groupby(["Age Ranges"]).mean()["Price"]
total_purch = purchase_data.groupby(["Age Ranges"]).sum()["Price"]

pd.DataFrame({"Purchase Count": purchase_count, "Average Purchase Price" : avg_price, "Total Purchse" : total_purch})
# Out:
#             Purchase Count  Average Purchase Price  Total Purchse
# Age Ranges
# <10                     23                3.353478          77.13
# 10-14                   28                2.956429          82.78
# 15-19                  136                3.035956         412.89
# 20-24                  365                3.052219        1114.06
# 25-29                  101                2.900990         293.00
# 30-34                   73                2.931507         214.00
# 35-39                   41                3.601707         147.67
# 40+                     13                2.941538          38.24

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#* SN
# * Purchase Count
# * Average Purchase Price
# * Total Purchase Value

purchase_count = purchase_data.groupby(["SN"]).count()["Price"]
avg_price = purchase_data.groupby(["SN"]).mean()["Price"]
total_purch = purchase_data.groupby(["SN"]).sum()["Price"]

pd.DataFrame({"Purchase Count": purchase_count, "Average Purchase Price" : avg_price, "Total Purchse" : total_purch})
# Out:
#                  Purchase Count  Average Purchase Price  Total Purchse
# SN
# Adairialis76                  1                2.280000           2.28
# Adastirin33                   1                4.480000           4.48
# Aeda94                        1                4.910000           4.91
# Aela59                        1                4.320000           4.32
# Aelaria33                     1                1.790000           1.79
# Aelastirin39                  2                3.645000           7.29
# Aelidru27                     1                1.090000           1.09
# Aelin32                       3                2.993333           8.98
# Aelly27                       2                3.395000           6.79
# Aellynun67                    1                3.740000           3.74
# Aellyria80                    1                3.080000           3.08
# Aelollo59                     2                2.815000           5.63
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
 # Item ID
  # Item Name
  # Purchase Count
  # Item Price
  # Total Purchase Value
    
purchase_count = purchase_data.groupby(["Item ID"]).count()["Price"]
avg_price = purchase_data.groupby(["Item ID"]).mean()["Price"]
total_purch = purchase_data.groupby(["Item ID"]).sum()["Price"]

pd.DataFrame({"Purchase Count": purchase_count, "Average Purchase Price" : avg_price, "Total Purchse" : total_purch})
# Out:
#          Purchase Count  Average Purchase Price  Total Purchse
# Item ID
# 0                     4                    1.28           5.12
# 1                     3                    3.26           9.78
# 2                     6                    2.48          14.88
# 3                     6                    2.49          14.94
# 4                     5                    1.70           8.50
# 5                     4                    4.08          16.32
# 6                     2                    3.70           7.40
# 7                     7                    1.33           9.31
# 8                     3                    3.93          11.79
# 9                     4                    2.73          10.92
# 10                    4                    1.79           7.16
# 11                    5                    3.65          18.25
# 12                    6                    1.02           6.12
# 13                    4                    1.41           5.64
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
  # Identify the 5 most profitable items by total purchase value, then list (in a table):
  # Item ID
  # Item Name
  # Purchase Count
  # Item Price
  # Total Purchase Value
  #ran out of time.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8cc9943c720a> in <module>()
#       5 # Item Price
#       6 # Total Purchase Value
# ----> 7 pd.DataFrame.sort_values("Total Purchase", ascending=False).head(5)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
